# %%
# Install the pytesseract Python package for optical character recognition (OCR)
pip install pytesseract
# Out:
#   Cell In[2], line 2
#     pip install pytesseract
#         ^
# SyntaxError: invalid syntax

# %%
# Install the OpenCV Python package without GUI support (headless)
pip install opencv-python-headless
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the OpenCV (cv2) and pytesseract libraries
import cv2
import pytesseract

# Import the os library for file operations
import os

# Import the pyplot module from matplotlib for image display
from matplotlib import pyplot as plt

# Import the re module for regular expressions
import re

# Import the cv2 module again (duplicate import, can be removed)
import cv2

# Import the numpy module as np
import numpy as np

# %%
# Import the Output class from the pytesseract module
#from pytesseract import Output

# Import the pyplot module from matplotlib for image display
#from matplotlib import pyplot as plt

# %%
# Specify the folder containing the images
folder_path = 'C:\\Users\\nsari\\OneDrive\\Desktop\\Sem 3\\Python\\ocr_project\\images'

# List all image files in the folder
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

# Loop through each image file and process it
for image_file in image_files:
    # Load the image using OpenCV
    image_path = os.path.join(folder_path, image_file)
    img = cv2.imread(image_path)

    if img is not None:
        # Convert BGR to RGB format
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Perform OCR using pytesseract
        text = pytesseract.image_to_string(img_rgb)

        # Print the recognized text
        print(f"Image: {image_file}\nRecognized Text:\n{text}\n")

        # Display the image using matplotlib
        plt.imshow(img_rgb)
        plt.axis('off')  # Turn off axis labels
        #plt.title(f"Image: {image_file}\nRecognized Text:\n{text}")  # Display image file name and recognized text as title
        plt.show()
# Out:
# Image: A.png
# Recognized Text:
# names = []
# for name, place in
# if place == ‘New York’ or place. == ‘Sydney’ or place =="Paris':
# names.
# print(names)
# Image: B.png
# Recognized Text:
# friends = [‘Radha Sharma’, ‘Anubhav’, ‘Arjun Verma’, ‘Anubhav’, ‘Ananya Reddy’, ‘Nandini Gupta’ ]
# ‘Anubhav’ in friends:
# +remove( ‘Anubhav")
# list(friends)
# Image: C.png
# Recognized Text:
# x = 88
# if x > 100:
#
# print("x is greater than 166")
# elif x == 100:
#
# print("x is equal to 10e")
# else:
#
# print("x is less than 1e@")
# Image: D.png
# Recognized Text:
# a=5
#
# def function_1():
# a=10
# print (a)
#
# def function_2():
# print (a)
#
# -function_1()
# function_2()
# Image: E.png
# Recognized Text:
# listi = [’A', 2, 3, 4, 5]
# list2=[1, 2, 3, 4, 5]
# list2.extend(list1)
#
# print (list1)
# Image: F.png
# Recognized Text:
# import pandas as pd
#
# frame7 = pd.DataFrame({"BLUE': [16, 9, 8, 5], ‘GREEN’: [6, 7, 8, 10]})
# ...
